# %% [markdown]
# # 尝试从binance公开数据库下载数据并且转换为qlib格式
#
# + 以 1min 数据为例进行尝试
# + 获取binance BTC-USDT
# + 数据分为daily更新和monthly更新，从daily下载

# %%
from binance_batch_downloader import BinanceBatchDownloader

batch_downloader = BinanceBatchDownloader(
    pairs=['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'BNBUSDT', 'DOGEUSDT'],
    download_path="binance_data_1min",
    start_date='2024-01-01',
    overwrite_mode=False,
    enable_logging=True 
)

# 执行下载
batch_downloader.download_all()

# 获取失败记录
failed_records = batch_downloader.get_failed_downloads()
print("详细失败记录:", failed_records)
# Out:
# [STATUS] 开始批量下载，交易对: ['BTCUSDT', 'ETHUSDT', 'SOLUSDT', 'XRPUSDT', 'BNBUSDT', 'DOGEUSDT'], 日期范围: 2024-01-01 到今天
# [STATUS] 模式: 更新模式
# [STATUS] 正在处理交易对: BTCUSDT
# 2026-04-18 19:03:23,242 - INFO - 确保目标目录存在: binance_data_1min/BTCUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:23,249 - INFO - 确保目标目录存在: binance_data_1min/BTCUSDT
#
# 2026-04-18 19:03:23,249 - INFO - 开始下载文件: BTCUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:24,301 - ERROR - 下载文件 BTCUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/BTCUSDT/1m/BTCUSDT-1m-2026-04-18.zip
#
# [STATUS] BTCUSDT 完成：成功 0，失败 1
# [STATUS] 正在处理交易对: ETHUSDT
# 2026-04-18 19:03:24,302 - INFO - 确保目标目录存在: binance_data_1min/ETHUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:24,312 - INFO - 确保目标目录存在: binance_data_1min/ETHUSDT
#
# 2026-04-18 19:03:24,312 - INFO - 开始下载文件: ETHUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/ETHUSDT/1m/ETHUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:25,816 - ERROR - 下载文件 ETHUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/ETHUSDT/1m/ETHUSDT-1m-2026-04-18.zip
#
# [STATUS] ETHUSDT 完成：成功 0，失败 1
# [STATUS] 正在处理交易对: SOLUSDT
# 2026-04-18 19:03:25,817 - INFO - 确保目标目录存在: binance_data_1min/SOLUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:25,835 - INFO - 确保目标目录存在: binance_data_1min/SOLUSDT
#
# 2026-04-18 19:03:25,835 - INFO - 开始下载文件: SOLUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/SOLUSDT/1m/SOLUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:26,791 - ERROR - 下载文件 SOLUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/SOLUSDT/1m/SOLUSDT-1m-2026-04-18.zip
#
# [STATUS] SOLUSDT 完成：成功 0，失败 1
# [STATUS] 正在处理交易对: XRPUSDT
# 2026-04-18 19:03:26,792 - INFO - 确保目标目录存在: binance_data_1min/XRPUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:26,810 - INFO - 确保目标目录存在: binance_data_1min/XRPUSDT
#
# 2026-04-18 19:03:26,810 - INFO - 开始下载文件: XRPUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/XRPUSDT/1m/XRPUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:27,491 - ERROR - 下载文件 XRPUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/XRPUSDT/1m/XRPUSDT-1m-2026-04-18.zip
#
# [STATUS] XRPUSDT 完成：成功 0，失败 1
# [STATUS] 正在处理交易对: BNBUSDT
# 2026-04-18 19:03:27,492 - INFO - 确保目标目录存在: binance_data_1min/BNBUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:27,510 - INFO - 确保目标目录存在: binance_data_1min/BNBUSDT
#
# 2026-04-18 19:03:27,510 - INFO - 开始下载文件: BNBUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/BNBUSDT/1m/BNBUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:28,248 - ERROR - 下载文件 BNBUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/BNBUSDT/1m/BNBUSDT-1m-2026-04-18.zip
#
# [STATUS] BNBUSDT 完成：成功 0，失败 1
# [STATUS] 正在处理交易对: DOGEUSDT
# 2026-04-18 19:03:28,249 - INFO - 确保目标目录存在: binance_data_1min/DOGEUSDT
#
# [STATUS] 更新模式：跳过 838 个已存在文件，将下载 1 个新文件
# 2026-04-18 19:03:28,267 - INFO - 确保目标目录存在: binance_data_1min/DOGEUSDT
#
# 2026-04-18 19:03:28,267 - INFO - 开始下载文件: DOGEUSDT-1m-2026-04-18.zip from https://data.binance.vision/data/futures/um/daily/klines/DOGEUSDT/1m/DOGEUSDT-1m-2026-04-18.zip
#
# 2026-04-18 19:03:28,874 - ERROR - 下载文件 DOGEUSDT-1m-2026-04-18.zip 失败: 404 Client Error: Not Found for url: https://data.binance.vision/data/futures/um/daily/klines/DOGEUSDT/1m/DOGEUSDT-1m-2026-04-18.zip
#
# [STATUS] DOGEUSDT 完成：成功 0，失败 1
# [STATUS] 批量下载完成！总计：成功 0，失败 6
# [STATUS] 下载失败统计：
# [STATUS]   BTCUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# [STATUS]   ETHUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# [STATUS]   SOLUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# [STATUS]   XRPUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# [STATUS]   BNBUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# [STATUS]   DOGEUSDT: 1 个文件失败
# [STATUS]     失败日期: ['2026-04-18']
# 详细失败记录: {'BTCUSDT': ['2026-04-18'], 'ETHUSDT': ['2026-04-18'], 'SOLUSDT': ['2026-04-18'], 'XRPUSDT': ['2026-04-18'], 'BNBUSDT': ['2026-04-18'], 'DOGEUSDT': ['2026-04-18']}

# %%
import pandas as pd
pd.read_csv('binance_data_1min/BTCUSDT/BTCUSDT-1m-2025-01-01.zip')
# Out:
#           open_time     open     high      low    close  volume  \
# 0     1735689600000  93548.8  93599.9  93514.2  93599.9  71.187
# 1     1735689660000  93599.9  93637.7  93577.6  93637.7  39.526
# 2     1735689720000  93637.7  93690.0  93614.2  93688.5  94.805
# 3     1735689780000  93688.5  93688.5  93626.4  93664.6  45.566
# 4     1735689840000  93664.5  93668.3  93626.3  93648.4  90.520
# ...             ...      ...      ...      ...      ...     ...
# 1435  1735775700000  94575.0  94591.8  94566.9  94586.4  41.234
# 1436  1735775760000  94586.3  94628.2  94586.3  94628.1  31.887
# 1437  1735775820000  94628.1  94645.8  94618.6  94618.6  45.564
# 1438  1735775880000  94618.6  94618.8  94584.5  94584.5  26.104
# 1439  1735775940000  94584.5  94593.4  94560.5  94580.9  68.991
#
#          close_time  quote_volume  count  taker_buy_volume  \
# 0     1735689659999  6.658942e+06   1660            35.553
# 1     1735689719999  3.699699e+06   1371            24.390
# 2     1735689779999  8.878465e+06   2376            60.198
# 3     1735689839999  4.267676e+06   1379            16.074
# 4     1735689899999  8.477821e+06   1390            12.103
# ...             ...           ...    ...               ...
# 1435  1735775759999  3.899983e+06    713            25.531
# 1436  1735775819999  3.016759e+06    646            27.416
# 1437  1735775879999  4.312214e+06    947            29.136
# 1438  1735775939999  2.469615e+06    685            11.968
# 1439  1735775999999  6.524941e+06   1143            28.190
#
#       taker_buy_quote_volume  ignore
# 0               3.325936e+06       0
# 1               2.282997e+06       0
# 2               5.637719e+06       0
# 3               1.505371e+06       0
# 4               1.133542e+06       0
# ...                      ...     ...
# 1435            2.414750e+06       0
# 1436            2.593733e+06       0
# 1437            2.757451e+06       0
# 1438            1.132257e+06       0
# 1439            2.666223e+06       0
#
# [1440 rows x 12 columns]

# %% [markdown]
# # 转化数据格式为qlib格式
#
# 分位多个模块：
# + 1.列名转化
# + 2.数据转化qlib格式
